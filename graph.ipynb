# %%
# 그래픽 위해
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# 1차원 데이터
plt.plot([1,10,5])

# %%
plt.bar(["Bike","Car","Book","PC"], [15,6,3,12], label="lotte")
# Out:
# <BarContainer object of 4 artists>

# %%
# 2차원 데이터
#plt.bar(["Bike","Car","Book","PC"], [15,6,3,12], label="lotte")
plt.plot(["Bike","Car","Book"], [5,10,7], label="emart", marker='o')
plt.plot(["Bike","Car","Book","PC"], [15,6,3,12], label="lotte")
plt.legend() # 범주표시
plt.xlabel("Product")
plt.ylabel("Price")
plt.title("Price Table")
plt.show() # 옵션 다 선택된대로 이미지 출력
